# %%
from crop_raman import crop_raman
import matplotlib.pyplot as plt
import os


sample = '00103993-1'
path = f'{os.environ["VSC_SCRATCH"]}/RAMALDI/{sample}/raman/ashlar.npy'

crop_raman(path, iterations=5, plot=True)
plt.show()
