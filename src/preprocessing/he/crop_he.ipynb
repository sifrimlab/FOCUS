# %%
from crop_he import read_he
import matplotlib.pyplot as plt
import os


sample = '00103993-1'
path = f'/mnt/data/lorenzo/VSC_DATA/Nina/{sample}/h&e'

read_he(path, iterations=1, plot=True)
plt.show()
# Out:
# /home/luna.kuleuven.be/u0172804/raman-maldi/src/preprocessing/he/crop_he.py:199: FutureWarning: The plugin infrastructure in `skimage.io` is deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not pass additional keyword arguments for plugins (`**plugin_args`). Instead, use `imageio` or other I/O packages directly. See also `skimage.io.imsave`.
#   skio.imsave(path_to_file, result, metadata = {'PhysicalSizeX': physical_size_x, 'PhysicalSizeY': physical_size_y})
